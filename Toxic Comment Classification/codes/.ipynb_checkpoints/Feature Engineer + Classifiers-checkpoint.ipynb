# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
import re
import gc



# %matplotlib inline

# %%
DATA_PATH = '../data/'
SUBMISSION_PATH = '../sub/'

# %%
df_train = pd.read_csv(DATA_PATH+"train.csv", sep = ",", header=0)
df_test = pd.read_csv(DATA_PATH+"test.csv", sep = ",", header=0)

# %%
# load different spellings of bad words in a dictionary
# key: different spelling form, val: root form if any
def bad_word_normalize(file_path):
    bad_word = {}
    with open(file_path, "r") as f:
        for line in f:
            line = line.strip().lower().split(", ")
            if len(line) == 1:
                bad_word[line[0].strip()] = line[0].strip()
            elif len(line) == 2: # different spelling of bad words return to dict
                bad_word[line[0].strip()] = line[1].strip()
            else:
                print("badwords.txt contains error line at:\n {}".format(line))
    return(bad_word)

BAD_WORD_DICT = bad_word_normalize(DATA_PATH+"badwords.txt")

# %% [markdown]
# ## Feature Engineering
# 1. **Number of (Unique) Words**
# 2. **Number of Puncuations**
# 3. **Number of Sentences**
# 4. **Number of Cap Words**
# 5. **Mis-spelling**
# 6. **Number of Bad Words**

# %%
def feature_engineer(df):
    
    # 1. number of words && number of unique words
    df['word_count'] = df['comment_text'].apply(lambda x: len(x.lower().split(' ')))
    df['uni_word_count'] = df['comment_text'].apply(lambda x: len(set(x.lower().split(' '))))

    # 2. number of puncuations: ! or ?
    punc_re = re.compile(r'[?!]+')
    df['punc_counts'] = df['comment_text'].apply(lambda x: len(punc_re.findall(x)))

    # 3. number of sentences
    sentence_re = re.compile(r'[.!?]+[ ]')
    df['sentence_count'] = df['comment_text'].apply(lambda x: len(sentence_re.split(x)))

    # 4. number of Caps
    cap_re = re.compile(r'\b[A-Z]{2,}\b') # all cap words with 2+ chars, (get rid of 'I', 'A')
    df['caps_count'] = df['comment_text'].apply(lambda x: len(cap_re.findall(x)))

    # 5. mis-spelling ?????
    
    # 6. number of bad words
    bad_word_set = set(BAD_WORD_DICT.keys())
    df['badword_count'] = df['comment_text'].apply(lambda x: sum(
        [len(re.findall(r'\b'+badword+r'\b', x.lower())) for badword in bad_word_set]))
    return(df)

# %%
df_train_test = pd.concat([df_train.iloc[:,:2], df_test.iloc[:,:2]], axis=0)
df_train_test = feature_engineer(df_train_test)

df_train_test.head(10)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-60-666b369c7f7e> in <module>()
#       1 df_train_test = pd.concat([df_train.iloc[:,:2], df_test.iloc[:,:2]], axis=0)
# ----> 2 df_train_test = feature_engineer(df_train_test)
#       3
#       4 df_train_test.head(10)
#
# <ipython-input-59-159faa16a94f> in feature_engineer(df)
#      21     # 6. number of bad words
#      22     bad_word_set = set(BAD_WORD_DICT.keys())
# ---> 23     df['badword_count'] = df['comment_text'].apply(lambda x: sum([len(re.findall(r'\b'+badword+r'\b', x.lower())) for badword in bad_word_set]))
#      24     return(df)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-59-159faa16a94f> in <lambda>(x)
#      21     # 6. number of bad words
#      22     bad_word_set = set(BAD_WORD_DICT.keys())
# ---> 23     df['badword_count'] = df['comment_text'].apply(lambda x: sum([len(re.findall(r'\b'+badword+r'\b', x.lower())) for badword in bad_word_set]))
#      24     return(df)
#
# <ipython-input-59-159faa16a94f> in <listcomp>(.0)
#      21     # 6. number of bad words
#      22     bad_word_set = set(BAD_WORD_DICT.keys())
# ---> 23     df['badword_count'] = df['comment_text'].apply(lambda x: sum([len(re.findall(r'\b'+badword+r'\b', x.lower())) for badword in bad_word_set]))
#      24     return(df)
#
# /anaconda3/lib/python3.6/re.py in findall(pattern, string, flags)
#     220
#     221     Empty matches are included in the result."""
# --> 222     return _compile(pattern, flags).findall(string)
#     223
#     224 def finditer(pattern, string, flags=0):
#
# /anaconda3/lib/python3.6/re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# /anaconda3/lib/python3.6/sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# /anaconda3/lib/python3.6/sre_parse.py in parse(str, flags, pattern)
#     853
#     854     try:
# --> 855         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     856     except Verbose:
#     857         # the VERBOSE flag was switched on inside the pattern.  to be
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     414     while True:
#     415         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 416                            not nested and not items))
#     417         if not sourcematch("|"):
#     418             break
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse(source, state, verbose, nested, first)
#     614             if not item or (_len(item) == 1 and item[0][0] is AT):
#     615                 raise source.error("nothing to repeat",
# --> 616                                    source.tell() - here + len(this))
#     617             if item[0][0] in _REPEATCODES:
#     618                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 2

# %%
re.findall(r'\btest\b', 'test traintest Test'.lower())
# Out:
# ['test', 'test']

# %%
pattern = 'test'
r'\b'+pattern+r'\b'
# Out:
# '\\btest\\b'

# %%
for badword in set(BAD_WORD_DICT.keys()):
    print(badword)
# Out:
# helvete
# feg
# pecker
# biatch
# butt-pirate
# b!tch
# cipa
# motha fukker
# spierdalaj
# fuck
# splooge
# cunts
# fukkah
# jism
# fuk*
# teets
# puto
# spic
# dike*
# nigger*
# paska*
# basterds
# penus
# knobs
# schmuck
# s t f u
# motha fuker
# assh0lez
# faget
# bollock*
# vullva
# blow job
# blowjob
# nigger
# h00r
# niigr
# tits
# injun
# qweerz
# shits
# buceta
# mother fukker
# packy
# sh1tter
# fanny
# felcher
# assholes
# wop*
# qweir
# futkretzn
# orgasim
# muschi
# hoorem whore
# vulva
# polak
# sadist
# gay
# queef*
# ekrem*
# hore
# kraut
# kuk
# bi+ch
# @ss
# hells
# guiena
# faig
# slutty
# b17ch
# cocks
# chink
# testical
# sh#t
# chuj
# titt*
# hui
# teez
# gays
# pussee
# basterdz
# sh!t
# asswipe
# prost!tute
# penis
# ekto
# wh00r. whore
# dildo
# ahole
# chraa
# jerk-off
# sh1tz
# picka
# fukin
# masterbate
# wetback*
# shyte
# sluts
# orgasum
# titt
# b00bs
# poontsee
# h0r
# g00k
# queers
# gaygirl
# cock*
# jackoff
# dild0s
# honkey
# yed
# azz
# 8ss
# fagit
# sphencter
# retard
# lipshitz
# hoer*
# assface
# mother fukkah
# motherfucker
# b00b*
# cunt
# f u c k e r
# pr1ck
# son-of-a-bitch
# fotze
# shi+
# hoar
# screwing
# cock-head
# japs
# fanculo
# fux0r
# piss*
# c0ck
# cawk
# arschloch
# sh1ter
# jizz
# pussy
# peenus
# ayir
# recktum
# asshole
# gook
# kurac
# pimpis
# shitter
# fatass
# ficken
# enculer
# shiz
# asholes
# merd*
# dyke
# penas
# ass
# testicle
# zabourah
# anus
# suka
# f ing
# testicle*
# kuntz
# masterbaiter
# mibun
# nepesaurio
# f uck
# ejakulate
# faigs
# massterbait
# penis-breath
# monkleigh
# kunts
# dilld0s
# skankee
# d*ck
# cum
# pakie
# *fuck*
# pen1s
# faggot
# skanks
# scrotum
# rectum
# schlong
# bitch*
# masterbat*
# sux
# pr1k
# preteen
# daygo
# fu
# muie
# peinus
# faen
# scank
# xxx
# masstrbate
# mutha fukker
# enema
# b1tch
# pule
# masstrbait
# peeenus
# mother fuker
# fuker
# puuke
# sh1ts
# wichser
# d!ck
# sharmute
# oriface
# foreskin
# nazi
# lesbian
# ash0le
# motha fukkah
# cock-sucker
# lesbo
# fag1t
# bi7ch
# boffing
# shitz
# shytty
# fuc
# cazzo
# whore
# xrated
# fukkin
# sh!+
# motha fucker
# mother-fucker
# vaj1na
# knulle
# b!+ch
# assrammer
# dominatrix
# feces
# mutha fukah
# dirsa
# nutsack
# twat
# cockhead
# turd
# fag
# shity
# qahbeh
# niiger
# penuus
# sh1t
# ash0les
# fuken
# sh!t*
# dik
# a$$
# shitty
# mutha fucker
# phuc
# sex
# fukken
# mouliewop
# masturbat*
# schlampe
# bastardz
# packi
# gayboy
# wh0re
# *damn
# vagina
# jap
# n1gr
# fu(*
# ass-hole
# skanky
# l3i+ch
# poonani
# skank
# kanker*
# polack
# amcik
# pimmel
# phuker
# wank*
# puta
# fart
# masochist
# bitch
# fucker
# fags
# shipal
# mamhoon
# a-hole
# dick
# shit
# skanck
# dominatrics
# smut
# huevon
# arse*
# va1jina
# wank
# whoar
# dominatricks
# w00se
# flikker
# phuck
# dick*
# polac
# buttwipe
# god-damned
# w t f
# schaffer
# hell
# orifice
# scheiss*
# carpet muncher
# mother fucker
# knobz
# crap
# clit
# mofo
# assholz
# cuntz
# hoorm whore
# fcuk
# fag*
# *shit*
# pr0n
# cabron
# orospu
# butthole
# clits
# mother fukah
# h4x0r
# qweers
# vagiina
# breasts
# c0k
# fukker
# vajina
# bassterds
# nigur
# fitt*
# s.o.b.
# ejackulate
# vag1na
# w0p
# mutha fuker
# bastards
# phukker
# dziwka
# peeenusss
# jiss
# @$$
# kusi*
# pillu*
# porn
# knob
# fagz
# kike
# boiolas
# paky
# queerz
# pizda
# fukk
# wtf
# fck
# cock
# fuckin
# sexy
# packie
# skurwysyn
# l3itch
# fudge packer
# slut
# klootzak
# poop
# cnts
# pr1c
# mulkku
# skribz
# dego
# b*tch
# fucking
# cunt*
# nastt
# fucks
# bastard
# vittu
# p0rn
# tit
# slutz
# orgasm
# hoer
# h0ar
# flipping the bird
# cntz
# cocksucker
# shyty
# masterbat3
# s.o.b
# *dyke
# sharmuta
# fuk
# a s s
# pula
# dildos
# nazis
# dilld0
# pusse
# phuk
# perse
# jizm
# kurwa
# masterbates
# boobs
# semen
# lezzian
# pierdol*
# orifiss
# d4mn
# assh0le
# f.ck
# kyrpa*
# idi0t
# fukah
# dupa
# gayz
# kawk
# kunt
# h0re
# bitches
# nigga
# f you
# orafis
# cawks
# shyt
# jisim
# masturbate
# masokist
# puuker
# dild0
# kuksuger
# fagg1t
# fu ck
# andskota
# lipshits
# paki
# ass monkey
# f u c k
# queer
# skankey
# mutha fukkah
# c0cks
# shemale
# faggit
# azzhole
# screw
# rautenberg

# %%
bad_word_set = set(BAD_WORD_DICT.keys())
df_train.iloc[:5, 1].apply(lambda x: )
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-62-5b2fde2ea389> in <module>()
#       1 bad_word_set = set(BAD_WORD_DICT.keys())
# ----> 2 df_train.iloc[:5, 1].apply(lambda x: sum(
#       3     [len(re.findall(r'\b'+badword+r'\b', x.lower())) for badword in bad_word_set]))
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-62-5b2fde2ea389> in <lambda>(x)
#       1 bad_word_set = set(BAD_WORD_DICT.keys())
#       2 df_train.iloc[:5, 1].apply(lambda x: sum(
# ----> 3     [len(re.findall(r'\b'+badword+r'\b', x.lower())) for badword in bad_word_set]))
#
# <ipython-input-62-5b2fde2ea389> in <listcomp>(.0)
#       1 bad_word_set = set(BAD_WORD_DICT.keys())
#       2 df_train.iloc[:5, 1].apply(lambda x: sum(
# ----> 3     [len(re.findall(r'\b'+badword+r'\b', x.lower())) for badword in bad_word_set]))
#
# /anaconda3/lib/python3.6/re.py in findall(pattern, string, flags)
#     220
#     221     Empty matches are included in the result."""
# --> 222     return _compile(pattern, flags).findall(string)
#     223
#     224 def finditer(pattern, string, flags=0):
#
# /anaconda3/lib/python3.6/re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# /anaconda3/lib/python3.6/sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# /anaconda3/lib/python3.6/sre_parse.py in parse(str, flags, pattern)
#     853
#     854     try:
# --> 855         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     856     except Verbose:
#     857         # the VERBOSE flag was switched on inside the pattern.  to be
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     414     while True:
#     415         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 416                            not nested and not items))
#     417         if not sourcematch("|"):
#     418             break
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse(source, state, verbose, nested, first)
#     614             if not item or (_len(item) == 1 and item[0][0] is AT):
#     615                 raise source.error("nothing to repeat",
# --> 616                                    source.tell() - here + len(this))
#     617             if item[0][0] in _REPEATCODES:
#     618                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 2

# %%
sum([len(re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower())) for badword in bad_word_set])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-63-6e8a7746b07f> in <module>()
# ----> 1 sum([len(re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower())) for badword in bad_word_set])
#
# <ipython-input-63-6e8a7746b07f> in <listcomp>(.0)
# ----> 1 sum([len(re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower())) for badword in bad_word_set])
#
# /anaconda3/lib/python3.6/re.py in findall(pattern, string, flags)
#     220
#     221     Empty matches are included in the result."""
# --> 222     return _compile(pattern, flags).findall(string)
#     223
#     224 def finditer(pattern, string, flags=0):
#
# /anaconda3/lib/python3.6/re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# /anaconda3/lib/python3.6/sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# /anaconda3/lib/python3.6/sre_parse.py in parse(str, flags, pattern)
#     853
#     854     try:
# --> 855         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     856     except Verbose:
#     857         # the VERBOSE flag was switched on inside the pattern.  to be
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     414     while True:
#     415         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 416                            not nested and not items))
#     417         if not sourcematch("|"):
#     418             break
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse(source, state, verbose, nested, first)
#     614             if not item or (_len(item) == 1 and item[0][0] is AT):
#     615                 raise source.error("nothing to repeat",
# --> 616                                    source.tell() - here + len(this))
#     617             if item[0][0] in _REPEATCODES:
#     618                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 2

# %%
df_train.iloc[5,1].lower()
# Out:
# '"\n\ncongratulations from me as well, use the tools well. \xa0· talk "'

# %%
[re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower()) for badword in bad_word_set]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-66-97b610498ccb> in <module>()
# ----> 1 [re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower()) for badword in bad_word_set]
#
# <ipython-input-66-97b610498ccb> in <listcomp>(.0)
# ----> 1 [re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower()) for badword in bad_word_set]
#
# /anaconda3/lib/python3.6/re.py in findall(pattern, string, flags)
#     220
#     221     Empty matches are included in the result."""
# --> 222     return _compile(pattern, flags).findall(string)
#     223
#     224 def finditer(pattern, string, flags=0):
#
# /anaconda3/lib/python3.6/re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# /anaconda3/lib/python3.6/sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# /anaconda3/lib/python3.6/sre_parse.py in parse(str, flags, pattern)
#     853
#     854     try:
# --> 855         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     856     except Verbose:
#     857         # the VERBOSE flag was switched on inside the pattern.  to be
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     414     while True:
#     415         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 416                            not nested and not items))
#     417         if not sourcematch("|"):
#     418             break
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse(source, state, verbose, nested, first)
#     614             if not item or (_len(item) == 1 and item[0][0] is AT):
#     615                 raise source.error("nothing to repeat",
# --> 616                                    source.tell() - here + len(this))
#     617             if item[0][0] in _REPEATCODES:
#     618                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 2

# %%
for badword in bad_word_set:
    print(r'\b'+badword+r'\b')
    print(re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower()))
# Out:
# \bhelvete\b
# []
# \bfeg\b
# []
# \bpecker\b
# []
# \bbiatch\b
# []
# \bbutt-pirate\b
# []
# \bb!tch\b
# []
# \bcipa\b
# []
# \bmotha fukker\b
# []
# \bspierdalaj\b
# []
# \bfuck\b
# []
# \bsplooge\b
# []
# \bcunts\b
# []
# \bfukkah\b
# []
# \bjism\b
# []
# \bfuk*\b
# []
# \bteets\b
# []
# \bputo\b
# []
# \bspic\b
# []
# \bdike*\b
# []
# \bnigger*\b
# []
# \bpaska*\b
# []
# \bbasterds\b
# []
# \bpenus\b
# []
# \bknobs\b
# []
# \bschmuck\b
# []
# \bs t f u\b
# []
# \bmotha fuker\b
# []
# \bassh0lez\b
# []
# \bfaget\b
# []
# \bbollock*\b
# []
# \bvullva\b
# []
# \bblow job\b
# []
# \bblowjob\b
# []
# \bnigger\b
# []
# \bh00r\b
# []
# \bniigr\b
# []
# \btits\b
# []
# \binjun\b
# []
# \bqweerz\b
# []
# \bshits\b
# []
# \bbuceta\b
# []
# \bmother fukker\b
# []
# \bpacky\b
# []
# \bsh1tter\b
# []
# \bfanny\b
# []
# \bfelcher\b
# []
# \bassholes\b
# []
# \bwop*\b
# []
# \bqweir\b
# []
# \bfutkretzn\b
# []
# \borgasim\b
# []
# \bmuschi\b
# []
# \bhoorem whore\b
# []
# \bvulva\b
# []
# \bpolak\b
# []
# \bsadist\b
# []
# \bgay\b
# []
# \bqueef*\b
# []
# \bekrem*\b
# []
# \bhore\b
# []
# \bkraut\b
# []
# \bkuk\b
# []
# \bbi+ch\b
# []
# \b@ss\b
# []
# \bhells\b
# []
# \bguiena\b
# []
# \bfaig\b
# []
# \bslutty\b
# []
# \bb17ch\b
# []
# \bcocks\b
# []
# \bchink\b
# []
# \btestical\b
# []
# \bsh#t\b
# []
# \bchuj\b
# []
# \btitt*\b
# []
# \bhui\b
# []
# \bteez\b
# []
# \bgays\b
# []
# \bpussee\b
# []
# \bbasterdz\b
# []
# \bsh!t\b
# []
# \basswipe\b
# []
# \bprost!tute\b
# []
# \bpenis\b
# []
# \bekto\b
# []
# \bwh00r. whore\b
# []
# \bdildo\b
# []
# \bahole\b
# []
# \bchraa\b
# []
# \bjerk-off\b
# []
# \bsh1tz\b
# []
# \bpicka\b
# []
# \bfukin\b
# []
# \bmasterbate\b
# []
# \bwetback*\b
# []
# \bshyte\b
# []
# \bsluts\b
# []
# \borgasum\b
# []
# \btitt\b
# []
# \bb00bs\b
# []
# \bpoontsee\b
# []
# \bh0r\b
# []
# \bg00k\b
# []
# \bqueers\b
# []
# \bgaygirl\b
# []
# \bcock*\b
# []
# \bjackoff\b
# []
# \bdild0s\b
# []
# \bhonkey\b
# []
# \byed\b
# []
# \bazz\b
# []
# \b8ss\b
# []
# \bfagit\b
# []
# \bsphencter\b
# []
# \bretard\b
# []
# \blipshitz\b
# []
# \bhoer*\b
# []
# \bassface\b
# []
# \bmother fukkah\b
# []
# \bmotherfucker\b
# []
# \bb00b*\b
# []
# \bcunt\b
# []
# \bf u c k e r\b
# []
# \bpr1ck\b
# []
# \bson-of-a-bitch\b
# []
# \bfotze\b
# []
# \bshi+\b
# []
# \bhoar\b
# []
# \bscrewing\b
# []
# \bcock-head\b
# []
# \bjaps\b
# []
# \bfanculo\b
# []
# \bfux0r\b
# []
# \bpiss*\b
# []
# \bc0ck\b
# []
# \bcawk\b
# []
# \barschloch\b
# []
# \bsh1ter\b
# []
# \bjizz\b
# []
# \bpussy\b
# []
# \bpeenus\b
# []
# \bayir\b
# []
# \brecktum\b
# []
# \basshole\b
# []
# \bgook\b
# []
# \bkurac\b
# []
# \bpimpis\b
# []
# \bshitter\b
# []
# \bfatass\b
# []
# \bficken\b
# []
# \benculer\b
# []
# \bshiz\b
# []
# \basholes\b
# []
# \bmerd*\b
# []
# \bdyke\b
# []
# \bpenas\b
# []
# \bass\b
# []
# \btesticle\b
# []
# \bzabourah\b
# []
# \banus\b
# []
# \bsuka\b
# []
# \bf ing\b
# []
# \btesticle*\b
# []
# \bkuntz\b
# []
# \bmasterbaiter\b
# []
# \bmibun\b
# []
# \bnepesaurio\b
# []
# \bf uck\b
# []
# \bejakulate\b
# []
# \bfaigs\b
# []
# \bmassterbait\b
# []
# \bpenis-breath\b
# []
# \bmonkleigh\b
# []
# \bkunts\b
# []
# \bdilld0s\b
# []
# \bskankee\b
# []
# \bd*ck\b
# []
# \bcum\b
# []
# \bpakie\b
# []
# \b*fuck*\b
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-71-577e13b9af5d> in <module>()
#       1 for badword in bad_word_set:
#       2     print(r'\b'+badword+r'\b')
# ----> 3     print(re.findall(r'\b'+badword+r'\b', df_train.iloc[5,1].lower()))
#
# /anaconda3/lib/python3.6/re.py in findall(pattern, string, flags)
#     220
#     221     Empty matches are included in the result."""
# --> 222     return _compile(pattern, flags).findall(string)
#     223
#     224 def finditer(pattern, string, flags=0):
#
# /anaconda3/lib/python3.6/re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# /anaconda3/lib/python3.6/sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# /anaconda3/lib/python3.6/sre_parse.py in parse(str, flags, pattern)
#     853
#     854     try:
# --> 855         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     856     except Verbose:
#     857         # the VERBOSE flag was switched on inside the pattern.  to be
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse_sub(source, state, verbose, nested)
#     414     while True:
#     415         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 416                            not nested and not items))
#     417         if not sourcematch("|"):
#     418             break
#
# /anaconda3/lib/python3.6/sre_parse.py in _parse(source, state, verbose, nested, first)
#     614             if not item or (_len(item) == 1 and item[0][0] is AT):
#     615                 raise source.error("nothing to repeat",
# --> 616                                    source.tell() - here + len(this))
#     617             if item[0][0] in _REPEATCODES:
#     618                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 2
